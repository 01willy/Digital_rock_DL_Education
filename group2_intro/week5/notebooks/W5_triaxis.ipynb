# %% [markdown]
# # Week 5 — Tri-Axis Aggregation — 본 연구 핵심 (2조 Intro)
#
# **2.5D Fusion (3 methods)**
#
# > 세 직교축 보간 결과를 GT-free 방식으로 융합
#
# ## 이번 주 학습 목표
# 1. z·y·x 각 축 inference 직접 실행
# 2. 3가지 GT-free aggregation 비교: tri_mean / tri_weuler_self / tri_consensus
# 3. 4 도메인 (BB·CG·Bentheimer·Parker) 결과 비교
# 4. 등방성 가정의 정량 검증
# 5. fig_aggregation_pareto 해석
#
# ## 학습 방식
# **"코드는 우리가 배포. 학생은 파라미터를 바꿔보며 결과 변화를 관찰한다."**
#
# > ⚠️ 본 노트북은 **skeleton (구조만)** 입니다.
# > 풀콘텐츠는 강사가 단계적으로 채워나갑니다. 본인이 미리 시도해도 좋습니다.

# %% [markdown]
# ## 0. 환경 준비

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve() / 'helpers'))
sys.path.insert(0, str(Path('..').resolve().parent / 'week2' / 'helpers'))  # W2 model_utils 재사용

import numpy as np
import matplotlib.pyplot as plt
try:
    import torch
except ImportError:
    print('torch not installed — run: pip install torch torchvision')

from dr_utils import setup_plot_style, ORANGE, NAVY, GREEN, RED, GRAY
setup_plot_style()
print('환경 준비 완료')

# %% [markdown]
# ## 1. z·y·x 각 축 inference 직접 실행

# %% [markdown]
# ## 2. 3가지 GT-free aggregation 비교: tri_mean / tri_weuler_self / tri_consensus

# %% [markdown]
# ## 3. 4 도메인 (BB·CG·Bentheimer·Parker) 결과 비교

# %% [markdown]
# ## 4. 등방성 가정의 정량 검증

# %% [markdown]
# ## 5. fig_aggregation_pareto 해석

# %%
# TODO: implement section 1
pass

# %%
# TODO: implement section 2
pass

# %%
# TODO: implement section 3
pass

# %%
# TODO: implement section 4
pass

# %%
# TODO: implement section 5
pass

# %% [markdown]
# ## 자기 점검 & 다음 주
#
# ### 자기 점검
# (W3-W6 풀콘텐츠 작성 시 5문항 추가 예정)
#
# ### 다음 주
# W6: Cross-domain (Carbonate) + LBM + 발표
#
# ---
#
# ## 🎯 W5 탐구 과제 (2조 Intro)
#
# **과제 1 (필수)**: 본 주제의 핵심 함수에 대해 주요 파라미터 sweep 수행.
#
# **과제 2 (필수)**: 학습/평가 결과를 W1, W2 결과와 직접 비교.
#
# **과제 3 (선택)**: 본인이 흥미있는 도메인/파라미터로 추가 탐구.
#
# *(상세 과제는 풀콘텐츠 작성 시 추가)*
